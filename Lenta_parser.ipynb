# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.9-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 5.9 MB/s
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=f2389054958853487fef8b7d1d9c2d6e3fb6343d812839ad91cfa4ee42204848
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.9 sgmllib3k-1.0.0

# %%
import feedparser
import csv
import pandas as pd
import re

# %%
newsurls = {'Lenta.ru': 'https://lenta.ru/rss/'} #пример словаря RSS-лент русскоязычных источников
f_all_news = 'lenta_news.csv'

# %%
def parseRSS( rss_url ): #функция получает линк на рсс ленту, возвращает распаршенную ленту с помощью feedpaeser
    return feedparser.parse( rss_url )  
    
def getHeadlines( rss_url ): #функция для получения заголовков новости
    headlines = []
    feed = parseRSS( rss_url )
    for newsitem in feed['items']:
        headlines.append(newsitem['title'])
    return headlines

def getDescriptions( rss_url ): #функция для получения описания новости
    descriptions = []
    feed = parseRSS( rss_url )
    for newsitem in feed['items']:
        descriptions.append(newsitem['description'])
    return descriptions

def getLinks( rss_url ): #функция для получения ссылки на источник новости
    links = []
    feed = parseRSS( rss_url )
    for newsitem in feed['items']:
        links.append(newsitem['link'])
    return links

def getDates( rss_url ): #функция для получения даты публикации новости
    dates = []
    feed = parseRSS( rss_url )
    for newsitem in feed['items']:
        dates.append(newsitem['published'])
    return dates

# %%
allheadlines = []
alldescriptions = []
alllinks = []
alldates = []
# Прогоняем нашии URL и добавляем их в наши пустые списки
for key,url in newsurls.items():
    allheadlines.extend( getHeadlines( url ) )
    
for key,url in newsurls.items():
    alldescriptions.extend( getDescriptions( url ) )
    
for key,url in newsurls.items():
    alllinks.extend( getLinks( url ) )
    
for key,url in newsurls.items():
    alldates.extend( getDates( url ) )

# %%
def write_all_news(all_news_filepath): #функция для записи всех новостей в .csv, возвращает нам этот датасет
    header = ['Title','Description','Links','Publication Date'] 

    with open(all_news_filepath, 'w', encoding='utf-8-sig') as csvfile:
        writer = csv.writer(csvfile, delimiter=',')
        writer.writerow(i for i in header) 
        for a,b,c,d  in zip(allheadlines, alldescriptions, alllinks, alldates):
            writer.writerow((a, b, c, d))
        df = pd.read_csv(all_news_filepath)
            
    return df

# %%
news_df = write_all_news(f_all_news) #все новости

# %%
news_df['Description'][0]
# Out:
# 'Национальное управление по аэронавтике и исследованию космического пространства сообщило, что зонд «Вояджер-1», запущенный 44 года назад (в 1977 году), начал отправлять на Землю неверные данные. Зонд на данный момент находится на расстоянии 23 миллиардов километров от Земли.'

# %%
news_df
# Out:
#                                                  Title  \
# 0    Самый удаленный от Земли зонд начал присылать ...
# 1    Германия и Италия разрешили открывать счета в ...
# 2    Названа причина остановки производства вакцин ...
# 3    Назван способ определить ложный звонок «из пол...
# 4    В России напомнили о провокации продовольствен...
# ..                                                 ...
# 192  Создан эффективный способ лечения смертоносной...
# 193  Семья американцев умерла при загадочных обстоя...
# 194  Повара посоветовали необычный способ усилить в...
# 195      Путин поручил оценить антироссийские меры ВТО
# 196  Командир бригады ВСУ Волына покинул «Азовсталь...
#
#                                            Description  \
# 0    Национальное управление по аэронавтике и иссле...
# 1    Власти Германии и Италии разрешили своим компа...
# 2    Замдиректора по научной работе ЦНИИ эпидемиоло...
# 3    Заслуженный юрист России Иван Соловьев рассказ...
# 4    Первый заместитель постоянного представителя Р...
# ..                                                 ...
# 192  Ученые Женской больницы Бригама в Бостоне созд...
# 193  Американская семья отправилась в отпуск на рос...
# 194  Повара посоветовали натирать посуду чесноком д...
# 195  Российский лидер Владимир Путин поручил правит...
# 196  Командир 36-й бригады морской пехоты Вооруженн...
#
#                                                  Links  \
# 0              https://lenta.ru/news/2022/05/21/nasa_/
# 1                https://lenta.ru/news/2022/05/21/gas/
# 2    https://lenta.ru/news/2022/05/21/proizvodstvo_...
# 3               https://lenta.ru/news/2022/05/21/call/
# 4              https://lenta.ru/news/2022/05/21/zapad/
# ..                                                 ...
# 192      https://lenta.ru/news/2022/05/19/celltherapy/
# 193      https://lenta.ru/news/2022/05/20/familydeath/
# 194          https://lenta.ru/news/2022/05/20/chesnok/
# 195     https://lenta.ru/news/2022/05/20/putin_analiz/
# 196     https://lenta.ru/news/2022/05/20/vol_azovstal/
#
#                     Publication Date
# 0    Sat, 21 May 2022 01:39:21 +0300
# 1    Sat, 21 May 2022 01:38:26 +0300
# 2    Sat, 21 May 2022 01:35:08 +0300
# 3    Sat, 21 May 2022 01:33:00 +0300
# 4    Sat, 21 May 2022 01:23:49 +0300
# ..                               ...
# 192  Fri, 20 May 2022 16:30:00 +0300
# 193  Fri, 20 May 2022 16:30:00 +0300
# 194  Fri, 20 May 2022 16:19:00 +0300
# 195  Fri, 20 May 2022 16:15:24 +0300
# 196  Fri, 20 May 2022 16:15:00 +0300
#
# [197 rows x 4 columns]

# %%
news_df.to_csv('/content/drive/MyDrive/lenta_parser/lenta_parser.csv', index=False)  # full ready data

# %%
df_res = pd.read_csv('/content/drive/MyDrive/lenta_parser/lenta_parser.csv')

# %%
df_res
# Out:
#                                                  Title  \
# 0    Самый удаленный от Земли зонд начал присылать ...
# 1    Германия и Италия разрешили открывать счета в ...
# 2    Названа причина остановки производства вакцин ...
# 3    Назван способ определить ложный звонок «из пол...
# 4    В России напомнили о провокации продовольствен...
# ..                                                 ...
# 192  Создан эффективный способ лечения смертоносной...
# 193  Семья американцев умерла при загадочных обстоя...
# 194  Повара посоветовали необычный способ усилить в...
# 195      Путин поручил оценить антироссийские меры ВТО
# 196  Командир бригады ВСУ Волына покинул «Азовсталь...
#
#                                            Description  \
# 0    Национальное управление по аэронавтике и иссле...
# 1    Власти Германии и Италии разрешили своим компа...
# 2    Замдиректора по научной работе ЦНИИ эпидемиоло...
# 3    Заслуженный юрист России Иван Соловьев рассказ...
# 4    Первый заместитель постоянного представителя Р...
# ..                                                 ...
# 192  Ученые Женской больницы Бригама в Бостоне созд...
# 193  Американская семья отправилась в отпуск на рос...
# 194  Повара посоветовали натирать посуду чесноком д...
# 195  Российский лидер Владимир Путин поручил правит...
# 196  Командир 36-й бригады морской пехоты Вооруженн...
#
#                                                  Links  \
# 0              https://lenta.ru/news/2022/05/21/nasa_/
# 1                https://lenta.ru/news/2022/05/21/gas/
# 2    https://lenta.ru/news/2022/05/21/proizvodstvo_...
# 3               https://lenta.ru/news/2022/05/21/call/
# 4              https://lenta.ru/news/2022/05/21/zapad/
# ..                                                 ...
# 192      https://lenta.ru/news/2022/05/19/celltherapy/
# 193      https://lenta.ru/news/2022/05/20/familydeath/
# 194          https://lenta.ru/news/2022/05/20/chesnok/
# 195     https://lenta.ru/news/2022/05/20/putin_analiz/
# 196     https://lenta.ru/news/2022/05/20/vol_azovstal/
#
#                     Publication Date
# 0    Sat, 21 May 2022 01:39:21 +0300
# 1    Sat, 21 May 2022 01:38:26 +0300
# 2    Sat, 21 May 2022 01:35:08 +0300
# 3    Sat, 21 May 2022 01:33:00 +0300
# 4    Sat, 21 May 2022 01:23:49 +0300
# ..                               ...
# 192  Fri, 20 May 2022 16:30:00 +0300
# 193  Fri, 20 May 2022 16:30:00 +0300
# 194  Fri, 20 May 2022 16:19:00 +0300
# 195  Fri, 20 May 2022 16:15:24 +0300
# 196  Fri, 20 May 2022 16:15:00 +0300
#
# [197 rows x 4 columns]
